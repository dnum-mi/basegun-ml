# %%
! pip install ultralytics
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ultralytics import YOLO

# %%
model= YOLO("yolov8n-pose.pt")
model.train(data='./config-pose.yaml',epochs=150, imgsz=640, batch=16, pretrained=True,patience=0,max_det=1, degrees=360, shear=0,flipud=0,fliplr=0,name="modeln150epcsEucliedeankeypoints5box5clsother0",box=5,pose=5, kobj=0,dfl=0,cls=1)
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.158 🚀 Python-3.9.5 torch-1.10.1+cu102 CPU (Intel Xeon Gold 6226R 2.90GHz)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
model= YOLO("yolov8n-pose.pt")
model.train(data='./configClassif.yaml',epochs=150, imgsz=640, batch=16, pretrained=True,patience=0,max_det=1, degrees=360, shear=0,flipud=0,fliplr=0,pose=0,name="modeln300epcsEucliedeanClassifKeypoint0")
# Out:
# New https://pypi.org/project/ultralytics/8.0.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.158 🚀 Python-3.9.5 torch-1.10.1+cu102 CPU (Intel Xeon Gold 6226R 2.90GHz)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...
